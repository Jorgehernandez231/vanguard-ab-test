# %%
import pandas as pd
import

# %%
df = pd.read_csv('df_final_demo_cleaned')

# %%
df.isnull().sum()
# Out:
# Unnamed: 0          0
# client_id           0
# clnt_tenure_yr      0
# clnt_tenure_mnth    0
# clnt_age            0
# gendr               0
# num_accts           0
# bal                 0
# calls_6_mnth        0
# logons_6_mnth       0
# dtype: int64

# %%
df[df.isnull().any(axis=1)]
# Out:
# Empty DataFrame
# Columns: [client_id, clnt_tenure_yr, clnt_tenure_mnth, clnt_age, gendr, num_accts, bal, calls_6_mnth, logons_6_mnth]
# Index: []

# %%
df['clnt_age'] = df['clnt_age'].fillna(df['clnt_age'].mean())

# %%
df = df.drop_duplicates()

# %%
df.gendr.unique()
# Out:
# array(['U', 'M', 'F', 'X'], dtype=object)

# %%
df
# Out:
#        Unnamed: 0  client_id  clnt_tenure_yr  clnt_tenure_mnth  clnt_age  \
# 0           59771        169              21               262      47.5
# 1           40126        555               3                46      29.5
# 2            1532        647              12               151      57.5
# 3           58466        722              11               143      59.5
# 4           13142        934               9               109      51.0
# ...           ...        ...             ...               ...       ...
# 70590       30538    9999400               7                86      28.5
# 70591        3228    9999626               9               113      35.0
# 70592       48756    9999729              10               124      31.0
# 70593        8011    9999832              23               281      49.0
# 70594       53845    9999839              13               160      28.5
#
#       gendr  num_accts        bal  calls_6_mnth  logons_6_mnth
# ...

# %%
df.columns = df.columns.str.strip().str.lower().str.replace(" ", "_")

# %%
df = df.sort_values(by="client_id", ascending=True)

# %%
df["clnt_tenure_yr"] = df["clnt_tenure_yr"].astype(int)
df["clnt_tenure_mnth"] = df["clnt_tenure_mnth"].astype(int)
df["num_accts"] = df["num_accts"].astype(int)
df["calls_6_mnth"] = df["calls_6_mnth"].astype(int)
df["logons_6_mnth"] = df["logons_6_mnth"].astype(int)

# %%
df.clnt_tenure_mnth.unique()
# Out:
# array([262.,  46., 151., 143., 109., 145.,  66.,  99.,  85., 576., 177.,
#         60., 150., 139., 229., 280., 260., 110., 157.,  98.,  63., 179.,
#        231., 142.,  58., 117., 116., 189., 190.,  75.,  94., 172., 199.,
#        154.,  86.,  77., 253., 361.,  57., 173.,  92., 329.,  72.,  81.,
#        149., 155.,  89., 195., 141., 106., 252., 218., 364., 140., 241.,
#        257., 226., 269., 170., 164.,  78., 108.,  56., 105.,  88., 211.,
#        205.,  73., 194.,  69., 171., 126.,  71.,  83., 121., 299., 156.,
#        285., 191., 321., 200.,  55.,  76., 242., 281., 294., 224., 166.,
#         70., 304.,  65., 169., 264., 230., 222., 160., 192.,  74.,  84.,
#         82., 168., 124., 119., 342., 219., 163., 144., 193., 131., 118.,
#        158.,  87., 186., 107., 196.,  91., 277., 125., 122., 259., 178.,
#        123., 310., 181., 232., 352., 214., 114., 250., 101.,  59., 345.,
#        282.,  80., 129.,  68., 184., 174., 268., 246., 176., 183.,  95.,
# ...

# %%
df.to_csv('df_final_demo_cleaned')

# %%
df_expe = pd.read_csv('df_final_experiment_clients.txt')

# %%
df_expe.isnull().sum()
# Out:
# client_id        0
# Variation    20109
# dtype: int64

# %%
df_expe
# Out:
#        client_id Variation
# 0        9988021      Test
# 1        8320017      Test
# 2        4033851   Control
# 3        1982004      Test
# 4        9294070   Control
# ...          ...       ...
# 50495     393005   Control
# 50496    2908510   Control
# 50497    7230446      Test
# 50498    5230357      Test
# 50499    6334360      Test
#
# [50500 rows x 2 columns]

# %%
df_expe[df_expe.isnull().any(axis=1)]
# Out:
# Empty DataFrame
# Columns: [client_id, variation]
# Index: []

# %%
df_expe = df_expe.drop_duplicates()

# %%
df_expe = df_expe.dropna()

# %%
df_expe.columns = df_expe.columns.str.strip().str.lower().str.replace(" ", "_")

# %%
df_expe.variation.unique()
# Out:
# array(['Test', 'Control'], dtype=object)

# %%
df.to_csv('df_final_demo_cleaned')
df_expe.to_csv('df_final_experiment_clients_cleaned')
